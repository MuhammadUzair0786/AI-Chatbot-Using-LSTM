# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

with open('intents.json') as file:
    data = json.load(file)
    
# empty lists to hold training data    
training_sentences = []
training_labels = []
labels = []
responses = []

# iterate over intents and patterns to create training data and labels
for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
   # add new tag to labels list if not already present 
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
# calculate number of classes        
num_classes = len(labels)


#--------------Start here preprocessing------------

#lable encoder use converting lables in numric form
# Initialize label encoder and fit it to the training labels
lbl_encoder = LabelEncoder()
#'fit' method trains the algorithm on the training data, after the model is initialized
lbl_encoder.fit(training_labels)

training_labels = lbl_encoder.transform(training_labels)

# Set the maximum vocabulary size, embedding dimension, maximum sequence length, and OOV token
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

# tokenization basically refers to splitting up a larger body of text into smaller words or lines
# Initialize tokenizer object and fit it to the training sentences
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)

# create word index from tokenizer
word_index = tokenizer.word_index

# convert training sentences to sequences and pad them
# Convert the training sentences to sequences and pad them to a maximum length of max_len
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# define and compile model
model = Sequential()
# Add an Embedding layer with the specified vocabulary size, embedding dimension, and sequence length
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
# Add a GlobalAveragePooling1D layer
model.add(GlobalAveragePooling1D())
# Add two Dense layers with ReLU activation
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with sparse categorical crossentropy loss and Adam optimizer
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# print model summary
model.summary()

# # Set the number of epochs for training
epochs = 500
# Fit the model to the padded sequences and training labels
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)


# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 16,680
# Trainable params: 16,680
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 2/2 [==============================] - 1s 13ms/step - loss: 2.0836 - accuracy: 0.1212
# Epoch 2/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0816 - accuracy: 0.1212
# Epoch 3/500
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0806 - accuracy: 0.1212
# Epoch 4/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0804 - accuracy: 0.1212
# Epoch 5/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0801 - accuracy: 0.1212
# Epoch 6/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0796 - accuracy: 0.1212
# Epoch 7/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0794 - accuracy: 0.1212
# Epoch 8/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0790 - accuracy: 0.1212
# Epoch 9/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0788 - accuracy: 0.1212
# Epoch 10/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0786 - accuracy: 0.1212
# Epoch 11/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0786 - accuracy: 0.1212
# Epoch 12/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0788 - accuracy: 0.1212
# Epoch 13/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0789 - accuracy: 0.1212
# Epoch 14/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0787 - accuracy: 0.1212
# Epoch 15/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0784 - accuracy: 0.1212
# Epoch 16/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0781 - accuracy: 0.1212
# Epoch 17/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0776 - accuracy: 0.1212
# Epoch 18/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0771 - accuracy: 0.1212
# Epoch 19/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0764 - accuracy: 0.1212
# Epoch 20/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0759 - accuracy: 0.1212
# Epoch 21/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0753 - accuracy: 0.1212
# Epoch 22/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0745 - accuracy: 0.1212
# Epoch 23/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0736 - accuracy: 0.1212
# Epoch 24/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0726 - accuracy: 0.1212
# Epoch 25/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0718 - accuracy: 0.1212
# Epoch 26/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0711 - accuracy: 0.1212
# Epoch 27/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0703 - accuracy: 0.1212
# Epoch 28/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0697 - accuracy: 0.1212
# Epoch 29/500
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0693 - accuracy: 0.1212
# Epoch 30/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0690 - accuracy: 0.1212
# Epoch 31/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0686 - accuracy: 0.1212
# Epoch 32/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0681 - accuracy: 0.1212
# Epoch 33/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0675 - accuracy: 0.1515
# Epoch 34/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0669 - accuracy: 0.1515
# Epoch 35/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0662 - accuracy: 0.1515
# Epoch 36/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0657 - accuracy: 0.1515
# Epoch 37/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0652 - accuracy: 0.1515
# Epoch 38/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0647 - accuracy: 0.1515
# Epoch 39/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0643 - accuracy: 0.1212
# Epoch 40/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0640 - accuracy: 0.1212
# Epoch 41/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0637 - accuracy: 0.1212
# Epoch 42/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0629 - accuracy: 0.1212
# Epoch 43/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0617 - accuracy: 0.1212
# Epoch 44/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0601 - accuracy: 0.1515
# Epoch 45/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0585 - accuracy: 0.1818
# Epoch 46/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0571 - accuracy: 0.2424
# Epoch 47/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0559 - accuracy: 0.2727
# Epoch 48/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0554 - accuracy: 0.3030
# Epoch 49/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0546 - accuracy: 0.3030
# Epoch 50/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0539 - accuracy: 0.3030
# Epoch 51/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0531 - accuracy: 0.3030
# Epoch 52/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0523 - accuracy: 0.3030
# Epoch 53/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0514 - accuracy: 0.3030
# Epoch 54/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0501 - accuracy: 0.3030
# Epoch 55/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0490 - accuracy: 0.3333
# Epoch 56/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0482 - accuracy: 0.3333
# Epoch 57/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0475 - accuracy: 0.3030
# Epoch 58/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0466 - accuracy: 0.3030
# Epoch 59/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0456 - accuracy: 0.3030
# Epoch 60/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0444 - accuracy: 0.2727
# Epoch 61/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0433 - accuracy: 0.2727
# Epoch 62/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0419 - accuracy: 0.2727
# Epoch 63/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0407 - accuracy: 0.2727
# Epoch 64/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0398 - accuracy: 0.2727
# Epoch 65/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0388 - accuracy: 0.2727
# Epoch 66/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0375 - accuracy: 0.2727
# Epoch 67/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0365 - accuracy: 0.2727
# Epoch 68/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0353 - accuracy: 0.2727
# Epoch 69/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0341 - accuracy: 0.2727
# Epoch 70/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0329 - accuracy: 0.2727
# Epoch 71/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0317 - accuracy: 0.2727
# Epoch 72/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0302 - accuracy: 0.2727
# Epoch 73/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0285 - accuracy: 0.2727
# Epoch 74/500
# 2/2 [==============================] - 0s 12ms/step - loss: 2.0268 - accuracy: 0.2727
# Epoch 75/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.0251 - accuracy: 0.2727
# Epoch 76/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0235 - accuracy: 0.2727
# Epoch 77/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0220 - accuracy: 0.2727
# Epoch 78/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0204 - accuracy: 0.2727
# Epoch 79/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0189 - accuracy: 0.3030
# Epoch 80/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0174 - accuracy: 0.4242
# Epoch 81/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0156 - accuracy: 0.3636
# Epoch 82/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0138 - accuracy: 0.3030
# Epoch 83/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0120 - accuracy: 0.3030
# Epoch 84/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0104 - accuracy: 0.3030
# Epoch 85/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0085 - accuracy: 0.3030
# Epoch 86/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0066 - accuracy: 0.3030
# Epoch 87/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0048 - accuracy: 0.3030
# Epoch 88/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0033 - accuracy: 0.3030
# Epoch 89/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0018 - accuracy: 0.3030
# Epoch 90/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0005 - accuracy: 0.3030
# Epoch 91/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9991 - accuracy: 0.3333
# Epoch 92/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9975 - accuracy: 0.3636
# Epoch 93/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.
500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4549 - accuracy: 0.5455
# Epoch 222/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4488 - accuracy: 0.5455
# Epoch 223/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4432 - accuracy: 0.5758
# Epoch 224/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4389 - accuracy: 0.5758
# Epoch 225/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4347 - accuracy: 0.5455
# Epoch 226/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4305 - accuracy: 0.5455
# Epoch 227/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4269 - accuracy: 0.5455
# Epoch 228/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4236 - accuracy: 0.5758
# Epoch 229/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4215 - accuracy: 0.5758
# Epoch 230/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4203 - accuracy: 0.5758
# Epoch 231/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4177 - accuracy: 0.5758
# Epoch 232/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4122 - accuracy: 0.5455
# Epoch 233/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4062 - accuracy: 0.5455
# Epoch 234/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4003 - accuracy: 0.5758
# Epoch 235/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3940 - accuracy: 0.5758
# Epoch 236/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3875 - accuracy: 0.5758
# Epoch 237/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3804 - accuracy: 0.5758
# Epoch 238/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3735 - accuracy: 0.5455
# Epoch 239/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3665 - accuracy: 0.5758
# Epoch 240/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3587 - accuracy: 0.6061
# Epoch 241/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3513 - accuracy: 0.6364
# Epoch 242/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3466 - accuracy: 0.6970
# Epoch 243/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3416 - accuracy: 0.7273
# Epoch 244/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3362 - accuracy: 0.7273
# Epoch 245/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3300 - accuracy: 0.6667
# Epoch 246/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3248 - accuracy: 0.6364
# Epoch 247/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3193 - accuracy: 0.6364
# Epoch 248/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3151 - accuracy: 0.6364
# Epoch 249/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3105 - accuracy: 0.6364
# Epoch 250/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3042 - accuracy: 0.6364
# Epoch 251/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2975 - accuracy: 0.6364
# Epoch 252/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2910 - accuracy: 0.6364
# Epoch 253/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2855 - accuracy: 0.6364
# Epoch 254/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2801 - accuracy: 0.6364
# Epoch 255/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2751 - accuracy: 0.6667
# Epoch 256/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2705 - accuracy: 0.6667
# Epoch 257/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2660 - accuracy: 0.6667
# Epoch 258/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2615 - accuracy: 0.6667
# Epoch 259/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2573 - accuracy: 0.7273
# Epoch 260/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2519 - accuracy: 0.7273
# Epoch 261/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2461 - accuracy: 0.7273
# Epoch 262/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2401 - accuracy: 0.7273
# Epoch 263/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2341 - accuracy: 0.7273
# Epoch 264/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2285 - accuracy: 0.6667
# Epoch 265/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2230 - accuracy: 0.6667
# Epoch 266/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2179 - accuracy: 0.6667
# Epoch 267/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2130 - accuracy: 0.6364
# Epoch 268/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2068 - accuracy: 0.6667
# Epoch 269/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2011 - accuracy: 0.6667
# Epoch 270/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1964 - accuracy: 0.7273
# Epoch 271/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1925 - accuracy: 0.7273
# Epoch 272/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1881 - accuracy: 0.7273
# Epoch 273/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1838 - accuracy: 0.7273
# Epoch 274/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1789 - accuracy: 0.7273
# Epoch 275/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1717 - accuracy: 0.7273
# Epoch 276/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1648 - accuracy: 0.7273
# Epoch 277/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1584 - accuracy: 0.7273
# Epoch 278/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1538 - accuracy: 0.7273
# Epoch 279/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1489 - accuracy: 0.7273
# Epoch 280/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1446 - accuracy: 0.7273
# Epoch 281/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1416 - accuracy: 0.7273
# Epoch 282/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1376 - accuracy: 0.6667
# Epoch 283/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1323 - accuracy: 0.6667
# Epoch 284/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1274 - accuracy: 0.6667
# Epoch 285/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1227 - accuracy: 0.6667
# Epoch 286/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1192 - accuracy: 0.6364
# Epoch 287/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1147 - accuracy: 0.6364
# Epoch 288/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1091 - accuracy: 0.6364
# Epoch 289/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1033 - accuracy: 0.6364
# Epoch 290/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0984 - accuracy: 0.6364
# Epoch 291/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0925 - accuracy: 0.6364
# Epoch 292/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0863 - accuracy: 0.6667
# Epoch 293/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0803 - accuracy: 0.6667
# Epoch 294/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0759 - accuracy: 0.6970
# Epoch 295/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0728 - accuracy: 0.6970
# Epoch 296/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0702 - accuracy: 0.6970
# Epoch 297/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0661 - accuracy: 0.7273
# Epoch 298/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0605 - accuracy: 0.7273
# Epoch 299/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0537 - accuracy: 0.7273
# Epoch 300/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0474 - accuracy: 0.7273
# Epoch 301/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0428 - accuracy: 0.6970
# Epoch 302/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0409 - accuracy: 0.6667
# Epoch 303/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0401 - accuracy: 0.6667
# Epoch 304/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0382 - accuracy: 0.6667
# Epoch 305/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0346 - accuracy: 0.6667
# Epoch 306/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0308 - accuracy: 0.6667
# Epoch 307/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0278 - accuracy: 0.6364
# Epoch 308/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0220 - accuracy: 0.6364
# Epoch 309/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0159 - accuracy: 0.6364
# Epoch 310/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0119 - accuracy: 0.6364
# Epoch 311/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0104 - accuracy: 0.6364
# Epoch 312/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0082 - accuracy: 0.6061
# Epoch 313/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0041 - accuracy: 0.6061
# Epoch 314/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9991 - accuracy: 0.6061
# Epoch 315/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9933 - accuracy: 0.6061
# Epoch 316/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9879 - accuracy: 0.6364
# Epoch 317/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9836 - accuracy: 0.6364
# Epoch 318/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9789 - accuracy: 0.6364
# Epoch 319/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9747 - accuracy: 0.6364
# Epoch 320/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9725 - accuracy: 0.6364
# Epoch 321/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9697 - accuracy: 0.6667
# Epoch 322/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9654 - accuracy: 0.6667
# Epoch 323/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9593 - accuracy: 0.6667
# Epoch 324/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9547 - accuracy: 0.6970
# Epoch 325/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9505 - accuracy: 0.6970
# Epoch 326/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9464 - accuracy: 0.6970
# Epoch 327/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9432 - accuracy: 0.6970
# Epoch 328/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9384 - accuracy: 0.6970
# Epoch 329/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9335 - accuracy: 0.6970
# Epoch 330/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9293 - accuracy: 0.7273
# Epoch 331/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9250 - accuracy: 0.7576
# Epoch 332/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9205 - accuracy: 0.7576
# Epoch 333/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9164 - accuracy: 0.6970
# Epoch 334/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9122 - accuracy: 0.7576
# Epoch 335/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9110 - accuracy: 0.7576
# Epoch 336/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9087 - accuracy: 0.7576
# Epoch 337/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9053 - accuracy: 0.7576
# Epoch 338/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9010 - accuracy: 0.7576
# Epoch 339/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8950 - accuracy: 0.7576
# Epoch 340/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8880 - accuracy: 0.7576
# Epoch 341/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8825 - accuracy: 0.7576
# Epoch 342/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8788 - accuracy: 0.7576
# Epoch 343/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8773 - accuracy: 0.7273
# Epoch 344/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8768 - accuracy: 0.6970
# Epoch 345/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8747 - accuracy: 0.6970
# Epoch 346/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8695 - accuracy: 0.6970
# Epoch 347/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8640 - accuracy: 0.6970
# Epoch 348/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8592 - accuracy: 0.6970
# Epoch 349/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8545 - accuracy: 0.7273
# Epoch 350/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8503 - accuracy: 0.7576
# Epoch 351/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8463 - accuracy: 0.7576
# Epoch 352/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8423 - accuracy: 0.7576
# Epoch 353/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8388 - accuracy: 0.7576
# Epoch 354/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8361 - accuracy: 0.7576
# Epoch 355/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8345 - accuracy: 0.7576
# Epoch 356/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8336 - accuracy: 0.7576
# Epoch 357/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8332 - accuracy: 0.7576
# Epoch 358/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8325 - accuracy: 0.7576
# Epoch 359/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8287 - accuracy: 0.7576
# Epoch 360/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8232 - accuracy: 0.7576
# Epoch 361/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8177 - accuracy: 0.7576
# Epoch 362/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8134 - accuracy: 0.7576
# Epoch 363/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8095 - accuracy: 0.7576
# Epoch 364/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8067 - accuracy: 0.7576
# Epoch 365/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8040 - accuracy: 0.7576
# Epoch 366/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8018 - accuracy: 0.7576
# Epoch 367/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7973 - accuracy: 0.7576
# Epoch 368/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7913 - accuracy: 0.7576
# Epoch 369/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7851 - accuracy: 0.7576
# Epoch 370/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7801 - accuracy: 0.7576
# Epoch 371/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7752 - accuracy: 0.7576
# Epoch 372/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7711 - accuracy: 0.7576
# Epoch 373/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7679 - accuracy: 0.7576
# Epoch 374/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7648 - accuracy: 0.7576
# Epoch 375/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7624 - accuracy: 0.7576
# Epoch 376/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7605 - accuracy: 0.7576
# Epoch 377/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7586 - accuracy: 0.7576
# Epoch 378/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7569 - accuracy: 0.7576
# Epoch 379/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7549 - accuracy: 0.7576
# Epoch 380/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7567 - accuracy: 0.7879
# Epoch 381/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7595 - accuracy: 0.7879
# Epoch 382/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7614 - accuracy: 0.7879
# Epoch 383/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7608 - accuracy: 0.7879
# Epoch 384/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7572 - accuracy: 0.7879
# Epoch 385/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7502 - accuracy: 0.8485
# Epoch 386/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7416 - accuracy: 0.8485
# Epoch 387/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7342 - accuracy: 0.8485
# Epoch 388/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7304 - accuracy: 0.8788
# Epoch 389/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7294 - accuracy: 0.8485
# Epoch 390/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7289 - accuracy: 0.8485
# Epoch 391/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7279 - accuracy: 0.8485
# Epoch 392/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7254 - accuracy: 0.8788
# Epoch 393/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7208 - accuracy: 0.8788
# Epoch 394/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7154 - accuracy: 0.8788
# Epoch 395/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7100 - accuracy: 0.9091
# Epoch 396/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7050 - accuracy: 0.9091
# Epoch 397/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7014 - accuracy: 0.9091
# Epoch 398/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6987 - accuracy: 0.9394
# Epoch 399/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6981 - accuracy: 0.9697
# Epoch 400/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6978 - accuracy: 0.9091
# Epoch 401/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.9091
# Epoch 402/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.9091
# Epoch 403/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6849 - accuracy: 0.9394
# Epoch 404/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6804 - accuracy: 0.9394
# Epoch 405/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6757 - accuracy: 0.9394
# Epoch 406/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6707 - accuracy: 0.9091
# Epoch 407/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6665 - accuracy: 0.9091
# Epoch 408/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6627 - accuracy: 0.9091
# Epoch 409/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6596 - accuracy: 0.9091
# Epoch 410/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6575 - accuracy: 0.9091
# Epoch 411/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6557 - accuracy: 0.9091
# Epoch 412/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6542 - accuracy: 0.9091
# Epoch 413/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6507 - accuracy: 0.9091
# Epoch 414/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6452 - accuracy: 0.9091
# Epoch 415/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6406 - accuracy: 0.9091
# Epoch 416/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6365 - accuracy: 0.9091
# Epoch 417/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6330 - accuracy: 0.9091
# Epoch 418/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6296 - accuracy: 0.9091
# Epoch 419/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6269 - accuracy: 0.9091
# Epoch 420/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6243 - accuracy: 0.8788
# Epoch 421/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6227 - accuracy: 0.8788
# Epoch 422/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6219 - accuracy: 0.8485
# Epoch 423/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6207 - accuracy: 0.8485
# Epoch 424/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6206 - accuracy: 0.8485
# Epoch 425/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6189 - accuracy: 0.8485
# Epoch 426/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6178 - accuracy: 0.8485
# Epoch 427/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6171 - accuracy: 0.7879
# Epoch 428/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6145 - accuracy: 0.7879
# Epoch 429/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.7879
# Epoch 430/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6042 - accuracy: 0.8485
# Epoch 431/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5983 - accuracy: 0.8485
# Epoch 432/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5932 - accuracy: 0.9091
# Epoch 433/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5922 - accuracy: 0.9091
# Epoch 434/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5924 - accuracy: 0.9091
# Epoch 435/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5931 - accuracy: 0.9091
# Epoch 436/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5913 - accuracy: 0.9091
# Epoch 437/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5890 - accuracy: 0.9697
# Epoch 438/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5855 - accuracy: 1.0000
# Epoch 439/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5824 - accuracy: 0.9697
# Epoch 440/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5801 - accuracy: 0.9394
# Epoch 441/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5781 - accuracy: 0.9091
# Epoch 442/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5768 - accuracy: 0.9091
# Epoch 443/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5760 - accuracy: 0.9091
# Epoch 444/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5750 - accuracy: 0.9091
# Epoch 445/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5746 - accuracy: 0.9091
# Epoch 446/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5741 - accuracy: 0.9091
# Epoch 447/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5715 - accuracy: 0.9091
# Epoch 448/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5684 - accuracy: 0.9091
# Epoch 449/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5659 - accuracy: 0.9091
# Epoch 450/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5639 - accuracy: 0.9091
# Epoch 451/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5618 - accuracy: 0.9091
# Epoch 452/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5601 - accuracy: 0.9091
# Epoch 453/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5582 - accuracy: 0.9091
# Epoch 454/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5566 - accuracy: 0.9091
# Epoch 455/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5542 - accuracy: 0.9091
# Epoch 456/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5519 - accuracy: 0.9091
# Epoch 457/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5481 - accuracy: 0.9091
# Epoch 458/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5431 - accuracy: 0.9091
# Epoch 459/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5380 - accuracy: 0.9091
# Epoch 460/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5336 - accuracy: 0.9091
# Epoch 461/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5325 - accuracy: 0.9697
# Epoch 462/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5327 - accuracy: 1.0000
# Epoch 463/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5341 - accuracy: 1.0000
# Epoch 464/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5353 - accuracy: 0.9697
# Epoch 465/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5351 - accuracy: 0.9697
# Epoch 466/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5323 - accuracy: 0.9697
# Epoch 467/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5286 - accuracy: 0.9697
# Epoch 468/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 1.0000
# Epoch 469/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5227 - accuracy: 1.0000
# Epoch 470/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5215 - accuracy: 1.0000
# Epoch 471/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 1.0000
# Epoch 472/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5204 - accuracy: 1.0000
# Epoch 473/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5183 - accuracy: 1.0000
# Epoch 474/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5165 - accuracy: 1.0000
# Epoch 475/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5152 - accuracy: 1.0000
# Epoch 476/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5139 - accuracy: 1.0000
# Epoch 477/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 1.0000
# Epoch 478/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5092 - accuracy: 1.0000
# Epoch 479/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 1.0000
# Epoch 480/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 1.0000
# Epoch 481/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 1.0000
# Epoch 482/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5046 - accuracy: 1.0000
# Epoch 483/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5044 - accuracy: 1.0000
# Epoch 484/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5014 - accuracy: 1.0000
# Epoch 485/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4948 - accuracy: 1.0000
# Epoch 486/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4891 - accuracy: 1.0000
# Epoch 487/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4854 - accuracy: 1.0000
# Epoch 488/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4833 - accuracy: 1.0000
# Epoch 489/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4822 - accuracy: 1.0000
# Epoch 490/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4816 - accuracy: 1.0000
# Epoch 491/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4793 - accuracy: 1.0000
# Epoch 492/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4765 - accuracy: 1.0000
# Epoch 493/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4741 - accuracy: 1.0000
# Epoch 494/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 1.0000
# Epoch 495/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4671 - accuracy: 1.0000
# Epoch 496/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4635 - accuracy: 1.0000
# Epoch 497/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 1.0000
# Epoch 498/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4558 - accuracy: 1.0000
# Epoch 499/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4510 - accuracy: 1.0000
# Epoch 500/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4491 - accuracy: 1.0000
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: chat_model\assets
# INFO:tensorflow:Assets written to: chat_model\assets
# Start messaging with the bot (type quit to stop)!
# User:

# %%
import json 
import numpy as np
from sklearn.preprocessing import LabelEncoder
import colorama 
from colorama import Fore, Style, Back
import random
import pickle
from tensorflow import keras

colorama.init()
# load intents.json file
with open("intents.json") as file:
    data = json.load(file)

# Define a function to start the chat
def chat():
    # load trained model
    try:
        model = keras.models.load_model('chat_model')
    except:
        # If loading fails due to optimizer, try loading with custom objects
        model = keras.models.load_model('chat_model', compile=False)
        model.compile(optimizer='adam')  # Recompile with a standard optimizer
    
    # rest of your code...

    # Load the tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # Load the label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # Parameters
    max_len = 20

    # Loop to take user input and get bot response
    while True:
        # Get user input
        inp = input("You: ")

        # Check if the user wants to quit
        if inp.lower() == "quit":
            break

        # Preprocess the input and predict the intent
        result = model.predict(
            keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                                       truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])[0]

        # Get a random response from the list of responses for the predicted intent
        for intent in data['intents']:
            if intent['tag'] == tag:
                response = random.choice(intent['responses'])
                print("Bot:", response)

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 51>()
#      48         # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))
#      50 print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
# ---> 51 chat()
#
# Input In [6], in chat()
#      16 def chat():
#      17     # load trained model
# ---> 18     model = keras.models.load_model('chat_model')
#      20     # load tokenizer object
#      21     with open('tokenizer.pickle', 'rb') as handle:
#
# File c:\Users\Muhammad Uzair\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\Muhammad Uzair\anaconda3\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:94, in _BaseOptimizer._process_kwargs(self, kwargs)
#      90   logging.warning(
#      91       "%s is deprecated in `optimizer_experimental.Optimizer`"
#      92       ", please check the docstring for valid arguments.", k)
#      93 else:
# ---> 94   raise TypeError(f"{k} is not a valid argument, kwargs should be empty "
#      95                   " for `optimizer_experimental.Optimizer`.")
#
# TypeError: weight_decay is not a valid argument, kwargs should be empty  for `optimizer_experimental.Optimizer`.
